# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:123456@localhost:3306

# %% [markdown]
# #### Normal Way

# %%
# %%sql
#
# create table tp_930_de.test_1 (
#     id int,
#     name varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %% [markdown]
# #### CTAS

# %%
# %%sql
#
# select * from tp_930_de.employees
# where city = 'Chennai';
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 7 rows affected.
# [(1, 'Gopal', 25, 'Male', Decimal('4591.25'), 'IT', '9710051702', 'Chennai'),
#  (15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
#  (41, 'Vasu', 22, 'Female', Decimal('41890.36'), 'Admin', '9272980699', 'Chennai'),
#  (54, 'Kalpana', 51, 'Female', Decimal('50237.50'), 'Finance', '9047116719', 'Chennai'),
#  (81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai'),
#  (84, 'Rani', 34, 'Male', Decimal('41284.76'), 'Finance', '9904228421', 'Chennai'),
#  (93, 'Karthik', 32, 'Female', Decimal('71215.90'), 'Marketing', '9550229612', 'Chennai')]

# %%
# %%sql
#
# create table tp_930_de.employees_male as
# select * from tp_930_de.employees
# where gender='Male';
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 49 rows affected.
# []

# %%
# %%sql
#
# select * from tp_930_de.employees_chennai;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 7 rows affected.
# [(1, 'Gopal', 25, 'Male', Decimal('4591.25'), 'IT', '9710051702', 'Chennai'),
#  (15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
#  (41, 'Vasu', 22, 'Female', Decimal('41890.36'), 'Admin', '9272980699', 'Chennai'),
#  (54, 'Kalpana', 51, 'Female', Decimal('50237.50'), 'Finance', '9047116719', 'Chennai'),
#  (81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai'),
#  (84, 'Rani', 34, 'Male', Decimal('41284.76'), 'Finance', '9904228421', 'Chennai'),
#  (93, 'Karthik', 32, 'Female', Decimal('71215.90'), 'Marketing', '9550229612', 'Chennai')]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 7 rows affected.
# [('employees',),
#  ('employees_chennai',),
#  ('employees_details',),
#  ('employees_dup',),
#  ('employees_male',),
#  ('test',),
#  ('test_1',)]

# %%
# %%sql
# select * from employees_details;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 100 rows affected.
# [(1, 'Gopal', 25, 'Male', 'IT'),
#  (2, 'Vignesh', 35, 'Male', 'R&D'),
#  (3, 'Naveen', 34, 'Female', 'Admin'),
#  (4, 'Deepa', 56, 'Female', 'Logistics'),
#  (5, 'Malathi', 38, 'Female', 'Operations'),
#  (6, 'Swathi', 50, 'Female', 'R&D'),
#  (7, 'Palani', 41, 'Male', 'Admin'),
#  (8, 'Krishnan', 46, 'Female', 'Finance'),
#  (9, 'Karthika', 45, 'Female', 'R&D'),
#  (10, 'Gopal', 37, 'Male', 'Finance'),
#  (11, 'Tamil', 54, 'Male', 'Support'),
#  (12, 'Parvathi', 52, 'Male', 'R&D'),
#  (13, 'Mala', 33, 'Female', 'Operations'),
#  (14, 'Ravi', 35, 'Male', 'IT'),
#  (15, 'Mala', 29, 'Female', 'Support'),
#  (16, 'Selva', 27, 'Male', 'Operations'),
#  (17, 'Rekha', 36, 'Male', 'R&D'),
#  (18, 'Vignesh', 46, 'Male', 'IT'),
#  (19, 'Vignesh', 24, 'Male', 'IT'),
#  (20, 'Anitha', 25, 'Male', 'Logistics'),
#  (21, 'Preethi', 37, 'Male', 'Operations'),
#  (22, 'Vanitha', 57, 'Male', 'Sales'),
# ...

# %%
# %%sql
# create table employees_details as
# select empId,name,age,gender,department from employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 100 rows affected.
# []

# %% [markdown]
# #### Temp Table

# %%
# %%sql
#
# create temporary table test_tep (
#     id int,
#     name varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %%
# %%sql
#
# insert into test_tep values (1,'gopal');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 1 rows affected.
# []

# %%
# %%sql
#
# select * from tp_930_de.test_employees_male_10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 10 rows affected.
# [(1, 'Gopal', 25, 'Male', Decimal('4591.25'), 'IT', '9710051702', 'Chennai'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
#  (11, 'Tamil', 54, 'Male', Decimal('62915.57'), 'Support', '9015430391', 'Coimbatore'),
#  (12, 'Parvathi', 52, 'Male', Decimal('93238.76'), 'R&D', '9227824896', 'Trichy'),
#  (14, 'Ravi', 35, 'Male', Decimal('15575.27'), 'IT', '9310518347', 'Trichy'),
#  (16, 'Selva', 27, 'Male', Decimal('47209.70'), 'Operations', '9133387262', 'Salem'),
#  (17, 'Rekha', 36, 'Male', Decimal('50450.46'), 'R&D', '9108013267', 'Tirunelveli'),
#  (18, 'Vignesh', 46, 'Male', Decimal('28170.97'), 'IT', '9647468723', 'Salem')]

# %%
# %%sql
#
#
# create temporary table tp_930_de.test_employees_male_10 as
# select * from tp_930_de.employees
# where gender = 'Male'
# limit 10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 10 rows affected.
# []

# %%
# %%sql
#
# alter table tp_930_de.employees
# add column increment int;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %%
# %%sql
#
# update tp_930_de.employees
# set increment = 4
# where empid = 45;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 1 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.employees
# order by age;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 100 rows affected.
# [(85, 'Sangeetha', 21, 'Female', Decimal('78198.77'), 'Sales', '9950240268', 'Coimbatore', None),
#  (33, 'Ravi', 21, 'Female', Decimal('37953.10'), 'Admin', '9995777387', 'Madurai', None),
#  (41, 'Vasu', 22, 'Female', Decimal('41890.36'), 'Admin', '9272980699', 'Chennai', None),
#  (87, 'Anand', 22, 'Male', Decimal('94886.94'), 'Admin', '9617711592', 'Coimbatore', None),
#  (46, 'Palani', 23, 'Female', Decimal('57619.62'), 'Operations', '9185067165', 'Tirunelveli', None),
#  (95, 'Swathi', 24, 'Male', Decimal('36768.23'), 'Admin', '9797643815', 'Vellore', None),
#  (19, 'Vignesh', 24, 'Male', Decimal('74838.04'), 'IT', '9097882081', 'Madurai', None),
#  (78, 'Rekha', 25, 'Male', Decimal('75332.12'), 'Sales', '9685160481', 'Tirunelveli', None),
#  (1, 'Gopal', 25, 'Male', Decimal('4591.25'), 'IT', '9710051702', 'Chennai', 2),
# ...

# %%
# %%sql
#
# insert into tp_930_de.employees (empid,number) values(102,9521818835)
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 1 rows affected.
# []

# %%
# %%sql
#
# select * from tp_930_de.employees
# order by empid desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 102 rows affected.
# [(102, None, None, None, None, None, '9521818835', None, None),
#  (101, None, None, None, None, None, None, None, None),
#  (100, 'Deepa', 46, 'Female', Decimal('74664.39'), 'Sales', '9521818835', 'Erode', None),
#  (99, 'Priya', 41, 'Male', Decimal('79105.77'), 'Logistics', '9751613696', 'Thanjavur', None),
#  (98, 'Ramesh', 46, 'Male', Decimal('49897.57'), 'Support', '9159696641', 'Vellore', None),
#  (97, 'Nirmala', 37, 'Female', Decimal('41249.79'), 'IT', '9762268388', 'Erode', None),
#  (96, 'Revathi', 39, 'Female', Decimal('57154.73'), 'Marketing', '9036900343', 'Madurai', None),
#  (95, 'Swathi', 24, 'Male', Decimal('36768.23'), 'Admin', '9797643815', 'Vellore', None),
#  (94, 'Manoj', 54, 'Male', Decimal('45095.55'), 'Support', '9525459910', 'Madurai', None),
#  (93, 'Karthik', 32, 'Female', Decimal('71215.90'), 'Marketing', '9550229612', 'Chennai', None),
# ...

# %%
# %%sql
#
# desc test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 2 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('name', 'varchar(100)', 'YES', '', None, '')]

# %%
# %%sql
#
# alter table test
# add primary key (id);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %%
# %%sql
#
# create table employees_without_dept as
# select empid,name,age,gender,salary,number,city,increment from employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 102 rows affected.
# []

# %%
# %%sql
#
# select * from employees_without_dept;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 102 rows affected.
# [(1, 'Gopal', 25, 'Male', Decimal('4591.25'), '9710051702', 'Chennai', 2),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), '9637940265', 'Salem', None),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), '9155940781', 'Vellore', None),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), '9593103413', 'Coimbatore', None),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), '9255341928', 'Trichy', None),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), '9350305641', 'Trichy', None),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), '9724238849', 'Vellore', None),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), '9871012269', 'Coimbatore', None),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), '9018451462', 'Tirunelveli', None),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), '9814893252', 'Thanjavur', None),
#  (11, 'Tamil', 54, 'Male', Decimal('62915.57'), '9015430391', 'Coimbatore', None),
# ...

# %%
# %%sql
#
# desc employees_without_dept;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 8 rows affected.
# [('empid', 'int', 'NO', 'PRI', None, ''),
#  ('name', 'varchar(100)', 'YES', '', None, ''),
#  ('age', 'int', 'YES', '', None, ''),
#  ('gender', 'varchar(10)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('number', 'varchar(10)', 'YES', '', None, ''),
#  ('city', 'varchar(50)', 'YES', '', None, ''),
#  ('increment', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# CREATE TABLE departments (
#     department_id INT PRIMARY KEY,
#     department_name VARCHAR(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %%
# %%sql
#
# alter table employees_without_dept
# add column department_id int ;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 0 rows affected.
# []

# %%
# %%sql
# alter table employees_without_dept
# add FOREIGN KEY (department_id)
#     REFERENCES departments(department_id);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 102 rows affected.
# []

# %%
# %%sql
#
# select * from employees_without_dept
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 102 rows affected.
# [(1, 'Gopal', 25, 'Male', Decimal('4591.25'), '9710051702', 'Chennai', 2, None),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), '9637940265', 'Salem', None, None),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), '9155940781', 'Vellore', None, 101),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), '9593103413', 'Coimbatore', None, None),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), '9255341928', 'Trichy', None, None),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), '9350305641', 'Trichy', None, None),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), '9724238849', 'Vellore', None, None),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), '9871012269', 'Coimbatore', None, None),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), '9018451462', 'Tirunelveli', None, None),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), '9814893252', 'Thanjavur', None, None),
# ...

# %%
# %%sql
# update employees_without_dept
# set department_id = 101
# where empid = 3;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 1 rows affected.
# []

# %%
# %%sql
#
# select * from departments;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 2 rows affected.
# [(101, 'IT'), (102, 'HR')]

# %%
# %%sql
#
# insert into departments values (101,'IT'),(102,'HR');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# 2 rows affected.
# []

# %%
# %%sql
# drop table departments;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306
# (mysql.connector.errors.DatabaseError) 3730 (HY000): Cannot drop table 'departments' referenced by a foreign key constraint 'employees_without_dept_ibfk_1' on table 'employees_without_dept'.
# [SQL: drop table departments;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
