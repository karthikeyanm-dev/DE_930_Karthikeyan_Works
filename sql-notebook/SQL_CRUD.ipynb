# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:123456@localhost:3306/

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 27 rows affected.
# [('db_test',),
#  ('de_test',),
#  ('information_schema',),
#  ('mysql',),
#  ('normalization',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sql_optimization',),
#  ('swiggy_db',),
#  ('sys',),
#  ('test',),
#  ('tp_11',),
#  ('tp_11_question',),
#  ('tp_11_quiz',),
#  ('tp_730',),
#  ('tp_730_db',),
#  ('tp_730_db_question',),
#  ('tp_730_db_quiz',),
#  ('tp_9',),
#  ('tp_930_de',),
#  ('tp_9_question',),
#  ('tp_9_quiz',),
#  ('tp_hr_payroll',),
#  ('tp_karthi',),
#  ('tp_karthi_quiz',),
#  ('world',),
#  ('zomato_db',)]

# %% [markdown]
# #### Create Table

# %%
# %%sql
# use tp_930_de;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# create table test(
# id int, name varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 2 rows affected.
# [('employees',), ('test',)]

# %% [markdown]
# #### Insertion 20 records
